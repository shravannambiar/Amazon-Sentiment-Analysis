# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import pickle
import gensim
import seaborn as sns
import sqlite3
import nltk
from nltk.corpus import stopwords
import re 
from sklearn.feature_extraction.text import CountVectorizer  ## BOW Model
from sklearn.feature_extraction.text import TfidfVectorizer  ## TFIDF Model

from sklearn.manifold import TSNE    ## To visualize high dimensional data

# %%
con.close()

# %%
con=sqlite3.connect("final_database.sqlite")
final=pd.read_sql_query("""
select * from Reviews 

""",con)

# %%
stop = set(stopwords.words('english')) #set of stopwords

# %%
sno = nltk.stem.SnowballStemmer('english') #initialising the snowball stemmer

# %%
def cleanhtml(sentence):
    '''This function removes all the html tags in the given sentence'''
    cleantext = re.sub('<.*?>', ' ', sentence)  ## Substitute <space> in place of any html tag
    return cleantext

# %%
def cleanpunc(sentence):
    '''This function cleans all the punctuation or special characters from a given sentence'''
    cleaned = re.sub(r'[?|@|!|^|%|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned

# %%
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here

# %%
def preprocessing(series):
    '''The function takes a Pandas Series object containing text in all the cells
       And performs following Preprocessing steps on each cell:
       1. Clean text from html tags
       2. Clean text from punctuations and special characters
       3. Retain only non-numeric Latin characters with lenght > 2
       4. Remove stopwords from the sentence
       5. Apply stemming to all the words in the sentence
       
       Return values:
       1. final_string - List of cleaned sentences
       2. list_of_sent - List of lists which can be used as input to the W2V model'''
    
    i = 0
    str1=" "
    final_string = []    ## This list will contain cleaned sentences
    list_of_sent = []    ## This is a list of lists used as input to the W2V model at a later stage
    
    
    
    for sent in series.values:
        ## 
        filtered_sent = []
        sent = cleanhtml(sent)    ## Clean the HTML tags
        sent = cleanpunc(sent)    ## Clean the punctuations and special characters
        ## Sentences are cleaned and words are handled individually
        for cleaned_words in sent.split():
            ## Only consider non-numeric words with length at least 3
            if((cleaned_words.isalpha()) and (len(cleaned_words) > 2)):
                ## Only consider words which are not stopwords and convert them to lowet case
                if(cleaned_words.lower() not in stop):
                    ## Apply snowball stemmer and add them to the filtered_sent list
                    s = (sno.stem(cleaned_words.lower()))#.encode('utf-8')
                    filtered_sent.append(s)    ## This contains all the cleaned words for a sentence
                    if (final['Score'].values)[i] == 'positive':
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final['Score'].values)[i] == 'negative':
                        all_negative_words.append(s) #list of all words used to describe negative reviews
        ## Below list is a list of lists used as input to W2V model later
        list_of_sent.append(filtered_sent)
        ## Join back all the words belonging to the same sentence
        str1 = " ".join(filtered_sent)
        ## Finally add the cleaned sentence in the below list
        final_string.append(str1)
        #print(i)
        i += 1
    return final_string, list_of_sent

# %%
print(stop)
# Out:
# {'below', 'what', 'yourselves', 'other', "hadn't", 'yours', "aren't", 'too', "you'd", 'how', 'y', 'himself', 'very', 'have', "it's", 'our', 'myself', 'as', 'been', 'over', "she's", 'with', 'they', 'o', 'in', "that'll", 'her', 'this', 'between', 'again', "weren't", "wouldn't", 'when', 'don', 'by', 'on', 'isn', "you'll", 'ain', 'aren', 'because', 'into', 'him', 'your', 'mustn', 'through', 'only', 'it', 've', 'of', 'd', 'you', 'themselves', 'were', 'to', 'both', 'ma', 'had', 'did', 't', 'above', 'that', 'but', 'their', 'mightn', 'most', 'should', "mustn't", "shouldn't", 'does', 'for', 'be', 'haven', 'itself', 'whom', 'being', 're', 'about', 'doesn', 'has', "isn't", 'a', 'me', 'up', "you've", 'such', 'from', 'now', 'hers', "shan't", 'during', 'at', 'here', 'own', "won't", 'weren', 'once', 'why', 'the', 'doing', 'each', 'all', 'any', 'we', 'and', 'theirs', 'hadn', 'shan', 'he', 'am', 'off', 'same', 'an', 'are', 'having', 'herself', 's', 'those', 'where', "mightn't", 'before', 'just', 'yourself', 'my', 'll', 'some', 'wouldn', 'is', 'which', 'his', 'then', 'couldn', 'if', 'so', "you're", 'no', 'who', 'i', 'or', 'more', 'ours', 'while', 'will', 'under', 'out', 'down', 'ourselves', 'them', 'these', 'was', 'than', "should've", 'shouldn', 'few', 'can', 'further', 'there', 'until', 'm', 'after', 'do', 'its', 'she'}

# %%
lst = ['won', 'nor', 'not', 'against']
for word in lst:
    stop.remove(word)
print(stop)
# Out:
# {'below', 'what', "needn't", 'yourselves', 'other', "hadn't", 'yours', "aren't", 'too', "don't", "you'd", 'how', 'y', 'himself', 'very', 'have', "it's", 'our', 'myself', 'as', 'wasn', 'been', 'over', "she's", 'with', 'they', 'o', 'in', "that'll", 'her', 'this', 'between', 'again', "weren't", "wouldn't", 'when', 'don', 'by', 'on', 'isn', "you'll", 'ain', "couldn't", 'aren', 'because', 'into', 'him', 'your', 'mustn', 'through', 'only', 'it', 've', 'hasn', "hasn't", 'of', 'didn', 'd', 'you', 'themselves', 'were', 'to', 'both', "didn't", 'ma', "haven't", 'had', 'did', 't', 'above', 'that', 'but', 'their', 'needn', 'mightn', 'most', 'should', "mustn't", "shouldn't", 'does', 'for', 'be', 'haven', 'itself', 'whom', 'being', 're', 'about', 'doesn', 'has', "isn't", 'a', 'me', 'up', "you've", 'such', 'from', 'now', 'hers', "shan't", 'during', 'at', 'here', 'own', "won't", 'weren', 'once', 'why', 'the', 'doing', 'each', 'all', 'any', 'we', 'and', 'theirs', 'hadn', 'shan', 'he', 'am', 'off', 'same', 'an', 'are', 'having', 'herself', 's', 'those', 'where', "mightn't", 'before', 'just', 'yourself', 'my', 'll', 'some', 'wouldn', 'is', 'which', 'his', 'then', 'couldn', "doesn't", 'if', 'so', "you're", 'no', 'who', 'i', 'or', 'more', "wasn't", 'ours', 'while', 'will', 'under', 'out', 'down', 'ourselves', 'them', 'these', 'was', 'than', "should've", 'shouldn', 'few', 'can', 'further', 'there', 'until', 'm', 'after', 'do', 'its', 'she'}

# %%
## This takes around 1 hour
final_string, list_of_sent=preprocessing(final["Text"])

# %%
len(list_of_sent)
# Out:
# 364171

# %%
type(final["Text"])
# Out:
# pandas.core.series.Series

# %%
final_string[0]
# Out:
# 'charm rhyme book describ circumst eat dont chicken soup rice sound like kind thing kid would make theyr recess sing drive teacher crazi cute catchi sound realli childlik skill written'

# %%
final["Text"][0]
# Out:
# "A charming, rhyming book that describes the circumstances under which you eat (or don't) chicken soup with rice, month-by-month. This sounds like the kind of thing kids would make up while they're out of recess and sing over and over until they drive the teachers crazy. It's cute and catchy and sounds really childlike but is skillfully written."

# %%
with open('list_of_positive_words.pkl', 'wb') as pickle_file:
    pickle.dump(all_positive_words, pickle_file)

# %%
all_positive_words
# Out:
# ['charm',
#  'rhyme',
#  'book',
#  'describ',
#  'circumst',
#  'eat',
#  'dont',
#  'chicken',
#  'soup',
#  'rice',
#  'sound',
#  'like',
#  'kind',
#  'thing',
#  'kid',
#  'would',
#  'make',
#  'theyr',
#  'recess',
#  'sing',
#  'drive',
#  'teacher',
#  'crazi',
#  'cute',
#  'catchi',
#  'sound',
#  'realli',
#  'childlik',
#  'skill',
#  'written',
#  'daughter',
#  'love',
#  'realli',
#  'rosi',
#  'book',
#  'introduc',
#  'realli',
#  'rosi',
#  'perform',
#  'carol',
#  'king',
#  'also',
#  'avail',
#  'amazon',
#  'birthday',
#  'year',
#  'later',
#  'know',
#  'song',
#  'far',
#  'book',
#  'one',
#  'johnni',
#  'allig',
#  'around',
#  'chicken',
#  'soup',
#  'rice',
#  'book',
#  'well',
#  'written',
#  'clever',
#  'art',
#  'work',
#  'mauric',
#  'sendak',
#  'plus',
#  'realli',
#  'cheap',
#  'high',
#  'recommend',
#  'witti',
#  'littl',
#  'book',
#  'make',
#  'son',
#  'laugh',
#  'loud',
#  'recit',
#  'car',
#  'drive',
#  'along',
#  'alway',
#  'sing',
#  'refrain',
#  'hes',
#  'learn',
#  'whale',
#  'india',
#  'droop',
#  'love',
#  'new',
#  'word',
#  'book',
#  'introduc',
#  'silli',
#  'classic',
#  'book',
#  'will',
#  'bet',
#  'son',
#  'still',
#  'abl',
#  'recit',
#  'memori',
#  'colleg',
#  'young',
#  'boy',
#  'describ',
#  'use',
#  'chicken',
#  'soup',
#  'rice',
#  'month',
#  'year',
#  'sendak',
#  'creativ',
#  'repetiti',
#  'rhythmic',
#  'word',
#  'children',
#  'enjoy',
#  'learn',
#  'read',
#  'stori',
#  'boy',
#  'love',
#  'chicken',
#  'soup',
#  'rice',
#  'sendak',
#  'catchi',
#  'stori',
#  'children',
#  'also',
#  'learn',
#  'month',
#  'year',
#  'well',
#  'season',
#  'month',
#  'learn',
#  'identifi',
#  'snowmen',
#  'strong',
#  'wind',
#  'bird',
#  'flower',
#  'swim',
#  'hot',
#  'temperatur',
#  'final',
#  'differ',
#  'holiday',
#  'throughout',
#  'year',
#  'halloween',
#  'octob',
#  'christma',
#  'decemb',
#  'sendak',
#  'simpl',
#  'three',
#  'color',
#  'draw',
#  'perfect',
#  'addit',
#  'educ',
#  'entertain',
#  'stori',
#  'great',
#  'activ',
#  'book',
#  'children',
#  'draw',
#  'illustr',
#  'month',
#  'year',
#  'afterward',
#  'bind',
#  'page',
#  'togeth',
#  'children',
#  'creat',
#  'book',
#  'book',
#  'contain',
#  'collect',
#  'twelv',
#  'short',
#  'statement',
#  'end',
#  'phrase',
#  'chicken',
#  'soup',
#  'rice',
#  'one',
#  'base',
#  'month',
#  'year',
#  'element',
#  'nonsens',
#  'vers',
#  'reason',
#  'children',
#  'find',
#  'entertain',
#  'generat',
#  'giggl',
#  'year',
#  'old',
#  'daughter',
#  'brought',
#  'book',
#  'home',
#  'school',
#  'librari',
#  'littl',
#  'easi',
#  'read',
#  'skill',
#  'love',
#  'anyway',
#  'year',
#  'old',
#  'daughter',
#  'start',
#  'read',
#  'cant',
#  'get',
#  'return',
#  'school',
#  'book',
#  'small',
#  'better',
#  'littl',
#  'hand',
#  'great',
#  'book',
#  'age',
#  'pictur',
#  'cute',
#  'well',
#  'write',
#  'rhyme',
#  'make',
#  'easi',
#  'get',
#  'know',
#  'month',
#  'recommend',
#  'book',
#  'everi',
#  'parent',
#  'book',
#  'purchas',
#  'birthday',
#  'gift',
#  'year',
#  'old',
#  'boy',
#  'squeal',
#  'delight',
#  'hug',
#  'told',
#  'keep',
#  'not',
#  'return',
#  'librari',
#  'ive',
#  'alway',
#  'love',
#  'chicken',
#  'soup',
#  'rice',
#  'late',
#  'ethel',
#  'alway',
#  'made',
#  'homemad',
#  'chicken',
#  'chicken',
#  'soup',
#  'rice',
#  'book',
#  'take',
#  'back',
#  'day',
#  'mother',
#  'father',
#  'sister',
#  'went',
#  'ethel',
#  'hous',
#  'late',
#  'isador',
#  'would',
#  'cook',
#  'chicken',
#  'ethel',
#  'blind',
#  'remind',
#  'time',
#  'togeth',
#  'famili',
#  'bring',
#  'back',
#  'happi',
#  'memori',
#  'love',
#  'share',
#  'bowl',
#  'hot',
#  'soup',
#  'great',
#  'book',
#  'perfect',
#  'condit',
#  'arriv',
#  'short',
#  'amount',
#  'time',
#  'long',
#  'expect',
#  'deliveri',
#  'date',
#  'classic',
#  'children',
#  'book',
#  'cant',
#  'wrong',
#  'read',
#  'kid',
#  'order',
#  'later',
#  'cant',
#  'beat',
#  'author',
#  'wrote',
#  'wild',
#  'thing',
#  'carol',
#  'king',
#  'wrote',
#  'great',
#  'song',
#  'match',
#  'lyric',
#  'illustr',
#  'fabul',
#  'wish',
#  'could',
#  'buy',
#  'hardbound',
#  'larger',
#  'tini',
#  'book',
#  'easili',
#  'misplac',
#  'carri',
#  'everywher',
#  'book',
#  'famili',
#  'favorit',
#  'read',
#  'children',
#  'small',
#  'order',
#  'new',
#  'famili',
#  'enjoy',
#  'great',
#  'book',
#  'ador',
#  'illustr',
#  'true',
#  'classic',
#  'kid',
#  'love',
#  'poem',
#  'music',
#  'goe',
#  'find',
#  'think',
#  'sung',
#  'carol',
#  'king',
#  'rememb',
#  'book',
#  'childhood',
#  'got',
#  'kid',
#  'good',
#  'rememb',
#  'kid',
#  'love',
#  'older',
#  'daughter',
#  'read',
#  'sister',
#  'good',
#  'rhyme',
#  'nice',
#  'pictur',
#  'june',
#  'saw',
#  'charm',
#  'group',
#  'rose',
#  'begin',
#  'droop',
#  'pep',
#  'chicken',
#  'soup',
#  'sprinkl',
#  'sprinkl',
#  'twice',
#  'sprinkl',
#  'chicken',
#  'soup',
#  'rice',
#  'great',
#  'book',
#  'teach',
#  'children',
#  'month',
#  'year',
#  'repetit',
#  'phrase',
#  'funni',
#  'littl',
#  'stori',
#  'accompani',
#  'pictur',
#  'make',
#  'ideal',
#  'bedtim',
#  'read',
#  'isnt',
#  'near',
#  'good',
#  'sendak',
#  'book',
#  'like',
#  'wild',
#  'thing',
#  'boy',
#  'didnt',
#  'care',
#  'still',
#  'carri',
#  'uniqu',
#  'brand',
#  'charm',
#  'set',
#  'asid',
#  'least',
#  'hour',
#  'day',
#  'read',
#  'son',
#  'point',
#  'consid',
#  'connoisseur',
#  'children',
#  'book',
#  'one',
#  'best',
#  'santa',
#  'claus',
#  'put',
#  'tree',
#  'sinc',
#  'weve',
#  'read',
#  'perpetu',
#  'love',
#  'first',
#  'book',
#  'taught',
#  'month',
#  'year',
#  'second',
#  'pleasur',
#  'read',
#  'well',
#  'suit',
#  'old',
#  'children',
#  'book',
#  'worth',
#  'own',
#  'borrow',
#  'librari',
#  'book',
#  'howev',
#  'deserv',
#  'perman',
#  'spot',
#  'shelf',
#  'sendak',
#  'best',
#  'chicken',
#  'soup',
#  'rice',
#  'mauric',
#  'sendak',
#  'josh',
#  'grossman',
#  'colonel',
#  'facp',
#  'rural',
#  'physician',
#  'author',
#  'step',
#  'would',
#  'believ',
#  'memor',
#  'book',
#  'would',
#  'believ',
#  'recit',
#  'month',
#  'order',
#  'would',
#  'believ',
#  'read',
#  'copi',
#  'tatter',
#  'read',
#  'children',
#  'profession',
#  'adult',
#  'would',
#  'believ',
#  'grandchildren',
#  'read',
#  'copi',
#  'tatter',
#  'confid',
#  'generat',
#  'children',
#  'enjoy',
#  'chicken',
#  'soup',
#  'rice',
#  'bravo',
#  'thank',
#  'respect',
#  'submit',
#  'book',
#  'poetri',
#  'month',
#  'year',
#  'goe',
#  'month',
#  'cute',
#  'littl',
#  'poem',
#  'along',
#  'love',
#  'book',
#  'realli',
#  'fun',
#  'way',
#  'learn',
#  'month',
#  'poem',
#  'creativ',
#  'author',
#  'purpos',
#  'write',
#  'book',
#  'give',
#  'children',
#  'fun',
#  'way',
#  'learn',
#  'month',
#  'children',
#  'also',
#  'learn',
#  'thing',
#  'poetri',
#  'rhythm',
#  'read',
#  'book',
#  'great',
#  'littl',
#  'book',
#  'read',
#  'nice',
#  'rhythm',
#  'well',
#  'good',
#  'repetit',
#  'littl',
#  'one',
#  'like',
#  'line',
#  'chicken',
#  'soup',
#  'rice',
#  'child',
#  'get',
#  'month',
#  'year',
#  'wonder',
#  'place',
#  'like',
#  'bombay',
#  'nile',
#  'eat',
#  'well',
#  'know',
#  'get',
#  'eat',
#  'kid',
#  'mauric',
#  'sendak',
#  'version',
#  'ice',
#  'skate',
#  'treat',
#  'rose',
#  'head',
#  'long',
#  'time',
#  'wont',
#  'even',
#  'know',
#  'came',
#  'surpris',
#  'came',
#  'littl',
#  'witti',
#  'book',
#  'fun',
#  'way',
#  'children',
#  'learn',
#  'month',
#  'year',
#  'learn',
#  'poem',
#  'throughout',
#  'school',
#  'year',
#  'like',
#  'handmot',
#  'invent',
#  'poem',
#  'grew',
#  'read',
#  'sendak',
#  'book',
#  'watch',
#  'realli',
#  'rosi',
#  'movi',
#  'incorpor',
#  'love',
#  'son',
#  'love',
#  'howev',
#  'miss',
#  'hard',
#  'cover',
#  'version',
#  'paperback',
#  'seem',
#  'kind',
#  'flimsi',
#  'take',
#  'two',
#  'hand',
#  'keep',
#  'page',
#  'open',
#  'get',
#  'movi',
#  'sound',
#  'track',
#  'sing',
#  'along',
#  'carol',
#  'king',
#  'great',
#  'stuff',
#  'whole',
#  'extend',
#  'famili',
#  'know',
#  'song',
#  'heart',
#  'qualiti',
#  'kid',
#  'storytel',
#  'music',
#  'entertain',
#  'rhyme',
#  'catchi',
#  'illustr',
#  'imagin',
#  'fit',
#  'right',
#  'howev',
#  'paperback',
#  'somewhat',
#  'small',
#  'flimsi',
#  'opt',
#  'bigger',
#  'edit',
#  'grand',
#  'daughter',
#  'favorit',
#  'book',
#  'read',
#  'love',
#  'rhythm',
#  'cute',
#  'stori',
#  'actual',
#  'enjoy',
#  'read',
#  'copi',
#  'smaller',
#  'expect',
#  'most',
#  'didnt',
#  'pay',
#  'attent',
#  'list',
#  'dimens',
#  'book',
#  'mauric',
#  'sendak',
#  'wonder',
#  'littl',
#  'book',
#  'month',
#  'rhyme',
#  'absolut',
#  'silli',
#  'much',
#  'fun',
#  'read',
#  'rememb',
#  'fond',
#  'child',
#  'want',
#  'make',
#  'sure',
#  'littl',
#  'one',
#  'book',
#  'shelf',
#  'cute',
#  'way',
#  'teach',
#  'month',
#  'year',
#  'not',
#  'mention',
#  'celebr',
#  'person',
#  'love',
#  'soup',
#  'beauti',
#  'illustr',
#  'way',
#  'sendak',
#  'rememb',
#  'see',
#  'show',
#  'air',
#  'televis',
#  'year',
#  'ago',
#  'child',
#  'sister',
#  'later',
#  'bought',
#  'day',
#  'thirti',
#  'someth',
#  'use',
#  'seri',
#  'book',
#  'song',
#  'student',
#  'teach',
#  'preschool',
#  'turn',
#  'whole',
#  'school',
#  'purchas',
#  'along',
#  'book',
#  'children',
#  'tradit',
#  'live',
#  'favorit',
#  'book',
#  'mine',
#  'littl',
#  'girl',
#  'would',
#  'read',
#  'time',
#  'mom',
#  'would',
#  'read',
#  'bedtim',
#  'book',
#  'two',
#  'copi',
#  'book',
#  'first',
#  'one',
#  'either',
#  'lost',
#  'given',
#  'away',
#  'found',
#  'anoth',
#  'copi',
#  'garag',
#  'sale',
#  'good',
#  'condit',
#  'buy',
#  'dont',
#  'know',
#  'around',
#  'somewher',
#  'probabl',
#  'attic',
#  'look',
#  'read',
#  'niec',
#  'recommend',
#  'book',
#  'book',
#  'favorit',
#  'mine',
#  'sinc',
#  'abl',
#  'read',
#  'one',
#  'first',
#  'introduct',
#  'poetri',
#  'humor',
#  'rhyme',
#  'inspir',
#  'write',
#  'type',
#  'book',
#  'colleg',
#  'student',
#  'reminisc',
#  'bond',
#  'realli',
#  'simpl',
#  'good',
#  'wonder',
#  'littl',
#  'book',
#  'love',
#  'year',
#  'ago',
#  'twin',
#  'love',
#  'enjoy',
#  'help',
#  'finish',
#  'month',
#  'sing',
#  'chicken',
#  'soup',
#  'rice',
#  'cute',
#  'draw',
#  'add',
#  'fun',
#  'warn',
#  'one',
#  'not',
#  'toto',
#  'day',
#  'person',
#  'say',
#  'chicken',
#  'soup',
#  'theyr',
#  'probabl',
#  'go',
#  'follow',
#  'word',
#  'soul',
#  'mayb',
#  'teenag',
#  'soul',
#  'didnt',
#  'use',
#  'way',
#  'rememb',
#  'time',
#  'person',
#  'said',
#  'chicken',
#  'soup',
#  'word',
#  'follow',
#  'enthusiast',
#  'rice',
#  'power',
#  'mauric',
#  'sendak',
#  'catchi',
#  'children',
#  'book',
#  'pleas',
#  'report',
#  'care',
#  'read',
#  'book',
#  'today',
#  'find',
#  'hasnt',
#  'dimish',
#  'jot',
#  'term',
#  'frolicksom',
#  'fun',
#  'book',
#  'led',
#  'whirlwind',
#  'chicken',
#  'soup',
#  'year',
#  'host',
#  'boy',
#  'bear',
#  'littl',
#  'resembl',
#  'sendak',
#  'great',
#  'rhyme',
#  'tale',
#  'pierr',
#  'look',
#  'not',
#  'demeanor',
#  'catchi',
#  'flounci',
#  'bounci',
#  'combo',
#  'soup',
#  'peopl',
#  'love',
#  'ostens',
#  'book',
#  'meant',
#  'teach',
#  'children',
#  'differ',
#  'month',
#  'year',
#  'month',
#  'get',
#  'rhythmic',
#  'poem',
#  'accompani',
#  'illustr',
#  'fair',
#  'simpl',
#  'pen',
#  'ink',
#  'draw',
#  'occasion',
#  'splash',
#  'blue',
#  'vari',
#  'shade',
#  'yellow',
#  'gray',
#  'green',
#  'may',
#  'wonder',
#  'author',
#  'could',
#  'ever',
#  'hope',
#  'come',
#  'twelv',
#  'high',
#  'origin',
#  ...]

# %%
final['CleanedText']=final_string #adding a column of CleanedText which displays the data after pre-processing of the review

# %%
(all_negative_words)
# Out:
# ['one',
#  'best',
#  'children',
#  'book',
#  'ever',
#  'written',
#  'mini',
#  'version',
#  'book',
#  'not',
#  'portray',
#  'one',
#  'price',
#  'product',
#  'sent',
#  'email',
#  'regard',
#  'bewilder',
#  'amazon',
#  'got',
#  'respons',
#  'give',
#  'five',
#  'star',
#  'mauric',
#  'sendak',
#  'stori',
#  'one',
#  'star',
#  'print',
#  'edit',
#  'book',
#  'children',
#  'older',
#  'copi',
#  'book',
#  'familiar',
#  'previous',
#  'softcov',
#  'version',
#  'order',
#  'granddaught',
#  'embarrass',
#  'give',
#  'gift',
#  'look',
#  'puni',
#  'book',
#  'size',
#  'postcard',
#  'think',
#  'overpr',
#  'ive',
#  'learn',
#  'not',
#  'buy',
#  'softcov',
#  'children',
#  'book',
#  'next',
#  'time',
#  'ill',
#  'get',
#  'use',
#  'copi',
#  'dog',
#  'love',
#  'chicken',
#  'product',
#  'china',
#  'wont',
#  'buy',
#  'anymor',
#  'hard',
#  'find',
#  'chicken',
#  'product',
#  'made',
#  'usa',
#  'one',
#  'isnt',
#  'bad',
#  'good',
#  'product',
#  'wont',
#  'take',
#  'chanc',
#  'till',
#  'know',
#  'go',
#  'china',
#  'import',
#  'price',
#  'foster',
#  'smith',
#  'select',
#  'compani',
#  'even',
#  'though',
#  'price',
#  'higher',
#  'hope',
#  'piec',
#  'would',
#  'consist',
#  'size',
#  'tuen',
#  'contain',
#  'fill',
#  'smaller',
#  'crum',
#  'like',
#  'piec',
#  'wors',
#  'compani',
#  'never',
#  'buy',
#  'anyth',
#  'compani',
#  'okay',
#  'liver',
#  'common',
#  'sens',
#  'tell',
#  'lot',
#  'less',
#  'price',
#  'treat',
#  'could',
#  'buy',
#  'real',
#  'liver',
#  'cube',
#  'freez',
#  'would',
#  'serv',
#  'purpos',
#  'lot',
#  'less',
#  'money',
#  'would',
#  'not',
#  'said',
#  'dog',
#  'would',
#  'back',
#  'flip',
#  'treat',
#  'your',
#  'made',
#  'money',
#  'ahead',
#  'youll',
#  'make',
#  'dog',
#  'day',
#  'receiv',
#  'contain',
#  'previous',
#  'open',
#  'seal',
#  'open',
#  'top',
#  'contain',
#  'decent',
#  'piec',
#  'liver',
#  'grisley',
#  'piec',
#  'lot',
#  'powder',
#  'bottom',
#  'never',
#  'buy',
#  'liver',
#  'treat',
#  'amazon',
#  'big',
#  'even',
#  'cheap',
#  'ribbon',
#  'trap',
#  'caught',
#  'mani',
#  'dozen',
#  'fli',
#  'day',
#  'ive',
#  'liquid',
#  'bait',
#  'trap',
#  'rescu',
#  'victor',
#  'fli',
#  'magnet',
#  'caught',
#  'hundr',
#  'day',
#  'thing',
#  'remain',
#  'empti',
#  'best',
#  'seem',
#  'rescu',
#  'trap',
#  'call',
#  'stinker',
#  'reek',
#  'work',
#  'trap',
#  'space',
#  'trap',
#  'hundr',
#  'fli',
#  'not',
#  'work',
#  'indoor',
#  'trap',
#  'direct',
#  'say',
#  'use',
#  'outdoor',
#  'protect',
#  'weather',
#  'time',
#  'spent',
#  'wait',
#  'order',
#  'fli',
#  'trap',
#  'arriv',
#  'went',
#  'bought',
#  'regular',
#  'fli',
#  'ribbon',
#  'bad',
#  'fli',
#  'problem',
#  'not',
#  'sure',
#  'kind',
#  'fli',
#  'slight',
#  'bigger',
#  'fruit',
#  'fli',
#  'least',
#  'week',
#  'ive',
#  'one',
#  'fli',
#  'trap',
#  'ive',
#  'caught',
#  'zero',
#  'fli',
#  'fli',
#  'trap',
#  'caught',
#  'probabl',
#  'fli',
#  'regular',
#  'fli',
#  'ribbon',
#  'one',
#  'point',
#  'even',
#  'saw',
#  'fli',
#  'fli',
#  'trap',
#  'thought',
#  'caught',
#  'gone',
#  'even',
#  'pictur',
#  'prove',
#  'hundr',
#  'common',
#  'hous',
#  'fli',
#  'hour',
#  'not',
#  'singl',
#  'one',
#  'caught',
#  'resort',
#  'fli',
#  'swatter',
#  'kill',
#  'hour',
#  'old',
#  'fli',
#  'swatter',
#  'fli',
#  'trap',
#  'appear',
#  'useless',
#  'fli',
#  'buzz',
#  'around',
#  'thing',
#  'like',
#  'not',
#  'even',
#  'mani',
#  'fli',
#  'around',
#  'think',
#  'luck',
#  'fli',
#  'would',
#  'least',
#  'bounc',
#  'stuck',
#  'pure',
#  'luck',
#  'not',
#  'singl',
#  'fli',
#  'caught',
#  'still',
#  'fli',
#  'annoy',
#  'buzz',
#  'around',
#  'area',
#  'not',
#  'catch',
#  'singl',
#  'fruit',
#  'fli',
#  'hous',
#  'fli',
#  'hors',
#  'fli',
#  'mosquito',
#  'even',
#  'hungri',
#  'spider',
#  'ant',
#  'cardboard',
#  'box',
#  'worth',
#  'nickel',
#  'spray',
#  'sticki',
#  'stuff',
#  'compani',
#  'laugh',
#  'bank',
#  'chicago',
#  'illinoi',
#  'let',
#  'put',
#  'way',
#  'fli',
#  'stay',
#  'trap',
#  'left',
#  'look',
#  'like',
#  'safe',
#  'island',
#  'fli',
#  'well',
#  'purchas',
#  'inexpens',
#  'figur',
#  'ship',
#  'might',
#  'well',
#  'two',
#  'differ',
#  'area',
#  'small',
#  'apart',
#  'hour',
#  'noth',
#  'ive',
#  'manag',
#  'kill',
#  'fli',
#  'swat',
#  'summer',
#  'grill',
#  'parti',
#  'door',
#  'kept',
#  'open',
#  'day',
#  'food',
#  'countertop',
#  'develop',
#  'horribl',
#  'fli',
#  'infest',
#  'home',
#  'husband',
#  'bought',
#  'trap',
#  'not',
#  'work',
#  'not',
#  'one',
#  'fli',
#  'caught',
#  'end',
#  'put',
#  'tini',
#  'smear',
#  'honey',
#  'one',
#  'side',
#  'actual',
#  'work',
#  'next',
#  'day',
#  'count',
#  'fli',
#  'thing',
#  'noth',
#  'attract',
#  'fli',
#  'someth',
#  'suppos',
#  'attract',
#  'flys',
#  'couldnt',
#  'care',
#  'less',
#  'month',
#  'time',
#  'caught',
#  'mayb',
#  'fli',
#  'sure',
#  'miniscul',
#  'fraction',
#  'kitchen',
#  'wast',
#  'money',
#  'problem',
#  'lot',
#  'fruit',
#  'fli',
#  'kitchen',
#  'pick',
#  'one',
#  'take',
#  'care',
#  'busi',
#  'despit',
#  'spotti',
#  'review',
#  'oop',
#  'sever',
#  'day',
#  'saw',
#  'one',
#  'fli',
#  'land',
#  'entir',
#  'time',
#  'best',
#  'part',
#  'tragic',
#  'stori',
#  'pick',
#  'trap',
#  'investig',
#  'one',
#  'trap',
#  'fli',
#  'darn',
#  'fli',
#  'didnt',
#  'pick',
#  'feet',
#  'take',
#  'that',
#  'right',
#  'fli',
#  'flew',
#  'away',
#  'land',
#  'none',
#  'fli',
#  'area',
#  'even',
#  'bother',
#  'call',
#  'sucker',
#  'trap',
#  'sucker',
#  'case',
#  'would',
#  'save',
#  'money',
#  'invest',
#  'quicker',
#  'hand',
#  'reflex',
#  'bought',
#  'local',
#  'hardwar',
#  'store',
#  'terribl',
#  'fli',
#  'problem',
#  'trap',
#  'one',
#  'fli',
#  'year',
#  'still',
#  'hang',
#  'still',
#  'one',
#  'fli',
#  'dont',
#  'buy',
#  'product',
#  'use',
#  'fli',
#  'sticki',
#  'tape',
#  'trap',
#  'garag',
#  'knat',
#  'fli',
#  'problem',
#  'also',
#  'fruit',
#  'fli',
#  'type',
#  'bug',
#  'fli',
#  'around',
#  'also',
#  'neghbor',
#  'big',
#  'fig',
#  'tree',
#  'isnt',
#  'prune',
#  'taken',
#  'care',
#  'fig',
#  'stay',
#  'tree',
#  'rot',
#  'till',
#  'dri',
#  'smell',
#  'realli',
#  'bad',
#  'attract',
#  'flys',
#  'garag',
#  'proxim',
#  'garag',
#  'put',
#  'caught',
#  'four',
#  'one',
#  'better',
#  'result',
#  'sticki',
#  'trap',
#  'unravel',
#  'caught',
#  'much',
#  'knat',
#  'bought',
#  'awhil',
#  'ago',
#  'decid',
#  'review',
#  'thing',
#  'suck',
#  'fli',
#  'caught',
#  'took',
#  'year',
#  'get',
#  'mayb',
#  'tini',
#  'microscop',
#  'fli',
#  'regular',
#  'fli',
#  'see',
#  'eye',
#  'still',
#  'caus',
#  'catch',
#  'fli',
#  'time',
#  'year',
#  'mayb',
#  'let',
#  'littl',
#  'thing',
#  'fli',
#  'around',
#  'could',
#  'get',
#  'real',
#  'fli',
#  'trap',
#  'actual',
#  'work',
#  'could',
#  'rate',
#  'fli',
#  'trap',
#  'lower',
#  'one',
#  'star',
#  'would',
#  'think',
#  'fli',
#  'come',
#  'mile',
#  'away',
#  'come',
#  'laugh',
#  'thing',
#  'success',
#  'take',
#  'fli',
#  'vat',
#  'scald',
#  'water',
#  'get',
#  'fli',
#  'random',
#  'run',
#  'box',
#  'ridicul',
#  'wast',
#  'infest',
#  'fruitfli',
#  'liter',
#  'everywher',
#  'fli',
#  'around',
#  'kitchen',
#  'bought',
#  'product',
#  'hope',
#  'least',
#  'get',
#  'rid',
#  'week',
#  'fli',
#  'stuck',
#  'go',
#  'around',
#  'notepad',
#  'squish',
#  'bugger',
#  'success',
#  'rate',
#  'day',
#  'clear',
#  'product',
#  'useless',
#  'even',
#  'dab',
#  'red',
#  'wine',
#  'banana',
#  'top',
#  'column',
#  'week',
#  'realli',
#  'attract',
#  'red',
#  'wine',
#  'glass',
#  'still',
#  'noth',
#  'get',
#  'stuck',
#  'actual',
#  'saw',
#  'second',
#  'fli',
#  'land',
#  'watch',
#  'flap',
#  'wing',
#  'frantic',
#  'within',
#  'sec',
#  'unstuck',
#  'product',
#  'total',
#  'wast',
#  'money',
#  'worst',
#  'product',
#  'gotten',
#  'long',
#  'time',
#  'would',
#  'rate',
#  'star',
#  'could',
#  'simpli',
#  'not',
#  'catch',
#  'singl',
#  'fli',
#  'bug',
#  'sort',
#  'went',
#  'hardwar',
#  'store',
#  'bought',
#  'spiral',
#  'fli',
#  'paper',
#  'effect',
#  'unuasu',
#  'influx',
#  'flys',
#  'hous',
#  'fall',
#  'need',
#  'someth',
#  'wish',
#  'read',
#  'review',
#  'make',
#  'purchas',
#  'basic',
#  'cardsotck',
#  'box',
#  'sticki',
#  'outsid',
#  'thing',
#  'look',
#  'like',
#  'entranc',
#  'trap',
#  'theyr',
#  'pictur',
#  'insid',
#  'trap',
#  'fli',
#  'stuck',
#  'outsid',
#  'basic',
#  'fli',
#  'paper',
#  'horribl',
#  'horribl',
#  'horribl',
#  'overpr',
#  'favor',
#  'get',
#  'fli',
#  'paper',
#  'fli',
#  'strip',
#  'yuck',
#  'factor',
#  'much',
#  'cheaper',
#  'mani',
#  'fli',
#  'hous',
#  'product',
#  'week',
#  'stuck',
#  'fli',
#  'thus',
#  'far',
#  'thing',
#  'item',
#  'trap',
#  'fruit',
#  'fli',
#  'didnt',
#  'work',
#  'fli',
#  'trap',
#  'wouldnt',
#  'recommend',
#  'okay',
#  'littl',
#  'garden',
#  'back',
#  'yard',
#  'attract',
#  'lot',
#  'fli',
#  'look',
#  'way',
#  'combat',
#  'hous',
#  'wasnt',
#  'sure',
#  'still',
#  'made',
#  'fli',
#  'paper',
#  'saw',
#  'search',
#  'great',
#  'amazon',
#  'excit',
#  'moment',
#  'open',
#  'box',
#  'dismay',
#  'serious',
#  'cannot',
#  'decid',
#  'joke',
#  'not',
#  'packag',
#  'say',
#  'box',
#  'stun',
#  'imag',
#  'draw',
#  'fli',
#  'imag',
#  'perhap',
#  'funniest',
#  'draw',
#  'ever',
#  'seen',
#  'call',
#  'product',
#  'not',
#  'caught',
#  'singl',
#  'fli',
#  'simpli',
#  'ignor',
#  'fli',
#  'everywher',
#  'stun',
#  'realist',
#  'imag',
#  'anyon',
#  'got',
#  'better',
#  'idea',
#  'not',
#  'buy',
#  'unless',
#  'play',
#  'joke',
#  'someon',
#  'dont',
#  'know',
#  'product',
#  'perform',
#  'big',
#  'fli',
#  'suck',
#  'fruit',
#  'fli',
#  'ineffect',
#  'worthless',
#  'bought',
#  'product',
#  'indoor',
#  'two',
#  'outdoor',
#  'fli',
#  'trap',
#  'outdoor',
#  'trap',
#  'work',
#  'immedi',
#  'notic',
#  'less',
#  'fli',
#  'home',
#  'backdoor',
#  'past',
#  'week',
#  'howev',
#  'indoor',
#  'trap',
#  'caught',
#  'zero',
#  'fli',
#  'yet',
#  'one',
#  'week',
#  'outdoor',
#  'trap',
#  'caught',
#  'combin',
#  'get',
#  'excit',
#  'look',
#  'trap',
#  'think',
#  'fli',
#  'caught',
#  'realiz',
#  'pictur',
#  'fli',
#  'dont',
#  'wast',
#  'money',
#  'product',
#  'place',
#  'around',
#  'hous',
#  'sever',
#  'day',
#  'setup',
#  'fli',
#  'attract',
#  'trap',
#  'vicin',
#  'liter',
#  'watch',
#  'fli',
#  'avoid',
#  'trap',
#  'day',
#  'excit',
#  'see',
#  'one',
#  'lilbugg',
#  'land',
#  'surfac',
#  'disappoint',
#  'approach',
#  'examin',
#  'flew',
#  'away',
#  'paper',
#  'tacki',
#  'pressur',
#  'human',
#  'finger',
#  'appli',
#  'small',
#  'fli',
#  'hard',
#  'trap',
#  'noth',
#  'cardboard',
#  'box',
#  'littl',
#  'dri',
#  'adhes',
#  'outsid',
#  'noth',
#  'attract',
#  'fli',
#  'adhes',
#  'not',
#  'gluey',
#  'enough',
#  'trap',
#  'happen',
#  'land',
#  'save',
#  'money',
#  'product',
#  'not',
#  'work',
#  'hang',
#  'kitchen',
#  'day',
#  'fli',
#  'attract',
#  'doesnt',
#  'worth',
#  'time',
#  'money',
#  'return',
#  'pleas',
#  'buyer',
#  'bewar',
#  'strong',
#  'suggest',
#  'find',
#  'item',
#  'pleas',
#  'not',
#  'wast',
#  'money',
#  'fli',
#  'trap',
#  'absolut',
#  'useless',
#  ...]

# %%
conn = sqlite3.connect('final.sqlite')
c=conn.cursor()
final.to_sql('Reviews', conn, if_exists='replace', index = False)
conn.close()

# %%
final
# Out:
#          index      Id   ProductId                 UserId  \
# 0       138693  150511  0006641040         A1C9K534BCI9GO
# 1       138708  150526  0006641040         A3E9QZFE9KXH8J
# 2       138707  150525  0006641040         A2QID6VCFTY51R
# 3       138706  150524  0006641040          ACITT7DI6IDDL
# 4       138705  150523  0006641040         A2P4F2UO0UMP8C
# 5       138704  150522  0006641040         A1S3C5OFU508P3
# 6       138703  150521  0006641040         A3RMCRB2NDTDYP
# 7       138702  150520  0006641040          ADBFSA9KTQANE
# 8       138701  150519  0006641040         A12HY5OZ2QNK4N
# 9       138700  150518  0006641040          AK1L4EJBA23JF
# 10      138699  150517  0006641040          ABW4IC5G5G8B5
# 11      138698  150516  0006641040         A3OI7ZGH6WZJ5G
# 12      138697  150515  0006641040         A2RTT81R6Y3R7X
# 13      138696  150514  0006641040          A2ONB6ZA292PA
# 14      138695  150513  0006641040          ASH0DZQQF6AIZ
# 15      138709  150529  0006641040          A25ACLV5KPB4W
# 16      138694  150512  0006641040         A1DJXZA5V5FFVA
# 17      138692  150510  0006641040          AM1MNZMYMS7D8
# 18      138691  150509  0006641040         A3CMRKGE0P909G
# 19      138690  150508  0006641040            AZGXZ2UUK6X
# 20      138689  150507  0006641040         A1S4A3IQ2MU7V4
# 21      138688  150506  0006641040         A2IW4PEEKO2R0U
# 22      138687  150505  0006641040         A2PTSM496CF40Z
# 23      138686  150504  0006641040          AQEYF1AXARWJZ
# 24      138685  150503  0006641040         A3R5XMPFU8YZ4D
# 25      138684  150502  0006641040          AVFMJ50HNO21J
# 26      138683  150501  0006641040          AJ46FKXOVC7NR
# 27      138682  150500  0006641040         A1IJKK6Q1GTEAY
# 28      138681  150499  0006641040         A3E7R866M94L0C
# 29      138680  150498  0006641040         A3SJWISOCP31TR
# ...        ...     ...         ...                    ...
# 364141   35419   38512  B009O7B1I0         A2YWHBF45M64S2
# 364142  195185  211594  B009O7DGEW         A2UAKIEWZLQCUE
# 364143  494393  534495  B009OY38SY         A1H1OCLG2B4AEQ
# 364144  134853  146374  B009P4KMZA         A217L3D5UK74I6
# 364145  430102  465120  B009PCDDO4         A2II09GQGWOMTQ
# 364146  264734  286941  B009PFJUF2         A2UAKIEWZLQCUE
# 364147  264735  286942  B009PFJUF2         A16HJRHRHNSUZ6
# 364148  241028  261429  B009PG8MVO         A2UAKIEWZLQCUE
# 364149  269822  292509  B009PIAFTE  A00489763J7YUCSN6CP7K
# 364150  343072  371148  B009PICJTS  A09229701Z8W88AD38877
# 364151  427660  462501  B009PIEW3O   A0849196AFU725N8S7RS
# 364152  184728  200383  B009RE0Y5G         A3M2YJ76LOMNBK
# 364153  178134  193163  B009RSR8HO         A1QX7TAALGCUKM
# 364154  178135  193164  B009RSR8HO         A2IZG2VYD476QH
# 364155  178137  193166  B009RSR8HO          AD0V42PRKCDBM
# 364156  178138  193167  B009RSR8HO          A5F9OUO3F2N7C
# 364157  178139  193168  B009RSR8HO         A1L130V9KINC45
# 364158  178140  193169  B009RSR8HO         A3M3S2NCVZ8UXF
# 364159  178141  193170  B009RSR8HO         A1TNEJA68OD7ZH
# 364160  178142  193171  B009RSR8HO          AH2FVNP7Z6PZH
# 364161  178143  193172  B009RSR8HO         A3JJTHP8T7A8LY
# 364162  178144  193173  B009RSR8HO         A34TVEXPHSSPBV
# 364163  178145  193174  B009RSR8HO          A4P6AN2L435PV
# 364164  178146  193175  B009RSR8HO         A1A0PMN417S4V9
# 364165  178147  193176  B009RSR8HO          A76WHW051R3KV
# 364166  178136  193165  B009RSR8HO         A1I08MP3H92U6R
# 364167  173675  188389  B009SF0TN6         A1L0GWGRK4BYPT
# 364168  204727  221795  B009SR4OQ2         A32A6X5KCP7ARG
# 364169    5259    5703  B009WSNWC4          AMP7K1O84DH1T
# 364170  302474  327601  B009WVB40S         A3ME78KVX31T21
#
#                                              ProfileName  \
# 0                                     Laura Purdie Salas
# 1                                            R. Mitchell
# 2                                                   Rick
# 3                                        shari zychinski
# 4                  Elizabeth A. Curry "Lovely Librarian"
# 5                                      Charles Ashbacher
# 6                                       Carol Carruthers
# 7                         James L. Hammock "Pucks Buddy"
# 8                                  Elizabeth H. Roessner
# 9                                            L. M. Kraus
# 10                                           kevin clark
# 11                           Mary Jane Rogers "Maedchen"
# 12                                               Lindylu
# 13                                      Rosalind Matzner
# 14                                              tessarat
# 15                                   Matt Hetling "Matt"
# 16                                             A. Conway
# 17                                  Dr. Joshua  Grossman
# 18                                                Teresa
# 19                           Catherine Hallberg "(Kate)"
# 20                                 sally sue "sally sue"
# 21                                                 Tracy
# 22      Jason A. Teeple "Nobody made a greater mistak...
# 23                             Les Sinclair "book maven"
# 24                         Her Royal Motherliness "Nana"
# 25                                              Jane Doe
# 26                                    Nicholas A Mesiano
# 27                                            A Customer
# 28                                L. Barker "simienwolf"
# 29                                           R. J. Wells
# ...                                                  ...
# 364141                                            EcyMom
# 364142                                          Cindy S.
# 364143                                            base64
# 364144                                     george karlin
# 364145                        Brian Nallick "METALMANMN"
# 364146                                          Cindy S.
# 364147                                    Danielle Tietz
# 364148                                          Cindy S.
# 364149                                      Andrea Llyod
# 364150                                     Kristi Greene
# 364151                                      Brady Gibson
# 364152                                          turbo418
# 364153                                       H.B. "H.B."
# 364154                                         CSTreviso
# 364155                                          Rachelle
# 364156                                               Jan
# 364157                                      mildred rosa
# 364158                                         Stephanie
# 364159                                            morgan
# 364160                                    Marty Campbell
# 364161                            Joanne Eklund "Joanne"
# 364162                                              Beth
# 364163                                            romarc
# 364164                               mamaelle "mamaelle"
# 364165                                     Shawn "Shawn"
# 364166                                            Thomas
# 364167                                     Bety Robinson
# 364168                                           sicamar
# 364169                                              ESTY
# 364170                                              K'la
#
#         HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                          0                       0  positive  1344211200
# 1                         11                      18  negative  1129507200
# 2                          1                       2  positive  1025481600
# 3                          0                       0  positive   939340800
# 4                          0                       0  positive  1096675200
# 5                          0                       0  positive  1219536000
# 6                          0                       0  positive  1243468800
# 7                          0                       0  positive  1256688000
# 8                          0                       0  positive  1256774400
# 9                          0                       0  positive  1288224000
# 10                         0                       0  positive  1291075200
# 11                         0                       0  positive  1293840000
# 12                         0                       0  positive  1303171200
# 13                         0                       0  positive  1313884800
# 14                         0                       0  positive  1325721600
# 15                         0                       1  positive  1108425600
# 16                         0                       0  positive  1338249600
# 17                         0                       0  positive  1348358400
# 18                         3                       4  positive  1018396800
# 19                         1                       1  positive  1076025600
# 20                         1                       1  positive  1191456000
# 21                         1                       1  positive  1194739200
# 22                         1                       1  positive  1210809600
# 23                         1                       1  positive  1212278400
# 24                         1                       1  positive  1233964800
# 25                         1                       1  positive  1324944000
# 26                         2                       2  positive   940809600
# 27                         2                       2  positive  1009324800
# 28                         2                       2  positive  1065830400
# 29                         2                       2  positive  1176336000
# ...                      ...                     ...       ...         ...
# 364141                     0                       0  negative  1350864000
# 364142                     0                       0  positive  1350777600
# 364143                     0                       0  positive  1350604800
# 364144                     0                       0  negative  1351036800
# 364145                     1                       1  positive  1350345600
# 364146                     1                       1  positive  1350777600
# 364147                     1                       1  positive  1350432000
# 364148                     0                       0  positive  1350777600
# 364149                     0                       0  positive  1351036800
# 364150                     0                       0  positive  1350518400
# 364151                     0                       0  positive  1350518400
# 364152                     0                       0  positive  1350864000
# 364153                     2                       2  positive  1350432000
# 364154                     1                       1  positive  1350432000
# 364155                     0                       0  positive  1350777600
# 364156                     0                       0  positive  1350604800
# 364157                     0                       0  positive  1350518400
# 364158                     0                       0  positive  1350518400
# 364159                     0                       0  positive  1350518400
# 364160                     0                       0  positive  1350432000
# 364161                     0                       0  positive  1350432000
# 364162                     0                       0  positive  1350432000
# 364163                     0                       0  positive  1350432000
# 364164                     0                       0  positive  1350432000
# 364165                     0                       0  positive  1350432000
# 364166                     1                       1  positive  1350432000
# 364167                     0                       0  positive  1350518400
# 364168                     1                       1  positive  1350604800
# 364169                     0                       0  positive  1351209600
# 364170                     0                       0  positive  1351123200
#
#                                                   Summary  \
# 0                                  Charming and childlike
# 1                                  awesome book poor size
# 2       In December it will be, my snowman's anniversa...
# 3                               EVERY book is educational
# 4                                   MMMM chicken soup....
# 5       Children will find it entertaining and a gener...
# 6                                     This book is great!
# 7                                              Great Gift
# 8                                      It's a great book!
# 9                                          love this book
# 10                                      good for children
# 11                                               Darling!
# 12                     One of our family's favorite books
# 13                                 Chicken soup with Rice
# 14                                              A classic
# 15                            Nice cadence, catchy rhymes
# 16                                             Must have.
# 17                                 Professional Mentoring
# 18                        A great way to learn the months
# 19                 a good swingy rhythm for reading aloud
# 20                          chicken soup with rice months
# 21             Love the book, miss the hard cover version
# 22                                              A classic
# 23                                 Chicken Soup with Rice
# 24                                         so fun to read
# 25             Tiny little book, Wonderful little rhymes.
# 26      This whole series is great way to spend time w...
# 27                                     It Was a favorite!
# 28                                      Can't explain why
# 29                                        A Gem of a Book
# ...                                                   ...
# 364141                                      Reprehensible
# 364142                                    Christmas Bulbs
# 364143                            Tastes good, works well
# 364144                   Another urine specimen from Cali
# 364145                                      Feeling blue?
# 364146                                      Amazing color
# 364147                   Looks very pretty when in bloom!
# 364148                  On the first day of Christmas....
# 364149                                    Truly delicious
# 364150                           One of the best I've had
# 364151                        Pure and Delicious Iced Tea
# 364152   This product is AMAZING!!! And way INEXPENSIVE!!
# 364153                 The Best Sweetener I've Ever Used!
# 364154                                   Love This Stuff!
# 364155                              Best sweetner ever!!!
# 364156                                      The Best Ever
# 364157                                     love sweetener
# 364158                                 Fat to Skinny zero
# 364159                        Fat to Skinny Zero Sweetner
# 364160          The BEST sugar replacement on the market!
# 364161                                               Zero
# 364162                                           Love it!
# 364163                                     LOVE!!  LOVE!!
# 364164                                 YAY! No Dextrose!!
# 364165                          My #1 Sweetener of choice
# 364166                  Would not use any other sweetener
# 364167              Amazing!! Great sauce for everything!
# 364168                                      Awesome Taste
# 364169                                          DELICIOUS
# 364170                                             Tasty!
#
#                                                      Text  \
# 0       A charming, rhyming book that describes the ci...
# 1       This is one of the best children's books ever ...
# 2       My daughter loves all the "Really Rosie" books...
# 3       this witty little book makes my son laugh at l...
# 4       Summary:  A young boy describes the usefulness...
# 5       This book contains a collection of twelve shor...
# 6       My 7 year old daughter brought this book home ...
# 7       This book was purchased as a birthday gift for...
# 8       I've always loved chicken soup and rice. My la...
# 9       Great book, perfect condition arrived in a sho...
# 10      Classic children's book, can't go wrong. I rea...
# 11      The same author wrote "Where the Wild Things A...
# 12      This book is a family favorite and was read to...
# 13      It's a great book with adorable illustrations....
# 14      I remembered this book from my childhood and g...
# 15      In June<br />I saw a charming group<br />of ro...
# 16      I set aside at least an hour each day to read ...
# 17      TITLE: Chicken Soup with Rice<br />AUTHOR: Mau...
# 18      This is a book of poetry about the months of t...
# 19      This is a great little book to read aloud- it ...
# 20      This is a fun way for children to learn their ...
# 21      I grew up reading these Sendak books, and watc...
# 22      Get the movie or sound track and sing along wi...
# 23      A very entertaining rhyming story--cleaver and...
# 24      This is my grand daughter's and my favorite bo...
# 25      This copy is smaller than I expected (mostly b...
# 26      I can remember seeing the show when it aired o...
# 27      This was a favorite book of mine when I was a ...
# 28      This book has been a favorite of mine since I ...
# 29      This is a wonderful little book. I loved it 40...
# ...                                                   ...
# 364141  This Trader Joe's product is good quality.  Bu...
# 364142  I gave these bulbs to the receptionist at my l...
# 364143  I tried this after reading the ingredients whi...
# 364144  The most watery and tasteless pinot noir on th...
# 364145  I usually drink Green Machine but I really wan...
# 364146  I have purchased several other Amaryllis from ...
# 364147  My neighborhood recently decided to create a n...
# 364148  ....my true love gave to me, a Christmas Bloom...
# 364149  I was a bit hesitant to buy this tea due to th...
# 364150  I am an avid tea drinker and enjoy my tea warm...
# 364151  My wife and I have been using unsweetened iced...
# 364152  Any product by My Personal Pantry is so delici...
# 364153  I have been using this product a bit over six ...
# 364154  Fat to Skinny Zero is a wonderful sweetener! I...
# 364155  This sweetner is so great. A little bit goes a...
# 364156  Zero sweetner is the BEST I have ever used.One...
# 364157  Great product not too expensive easy to use. S...
# 364158  I have been using this product for 4 months no...
# 364159  This is what I use when I'm baking instead of ...
# 364160  I've been using Fat to Skinny Zero since it wa...
# 364161  FTS Zero is the best sweetener I have ever tri...
# 364162  I love this sweetener.  I use it to replace su...
# 364163  LOVE, LOVE this sweetener!!  I use it in all m...
# 364164  Packets of powdered sweeteners usually have a ...
# 364165  What a wonderful product! It's perfect to use ...
# 364166  I have been using the Fat To Skinny Zero sweet...
# 364167  You have to try this sauce to believe it! It s...
# 364168  I bought this Hazelnut Paste (Nocciola Spread)...
# 364169  Purchased this product at a local store in NY ...
# 364170  I purchased this to send to my son who's away ...
#
#                                               CleanedText
# 0       charm rhyme book describ circumst eat dont chi...
# 1       one best children book ever written mini versi...
# 2       daughter love realli rosi book introduc realli...
# 3       witti littl book make son laugh loud recit car...
# 4       young boy describ use chicken soup rice month ...
# 5       book contain collect twelv short statement end...
# 6       year old daughter brought book home school lib...
# 7       book purchas birthday gift year old boy squeal...
# 8       ive alway love chicken soup rice late ethel al...
# 9       great book perfect condit arriv short amount t...
# 10      classic children book cant wrong read kid orde...
# 11      author wrote wild thing carol king wrote great...
# 12      book famili favorit read children small order ...
# 13      great book ador illustr true classic kid love ...
# 14      rememb book childhood got kid good rememb kid ...
# 15      june saw charm group rose begin droop pep chic...
# 16      set asid least hour day read son point consid ...
# 17      chicken soup rice mauric sendak josh grossman ...
# 18      book poetri month year goe month cute littl po...
# 19      great littl book read nice rhythm well good re...
# 20      fun way children learn month year learn poem t...
# 21      grew read sendak book watch realli rosi movi i...
# 22      get movi sound track sing along carol king gre...
# 23      entertain rhyme catchi illustr imagin fit righ...
# 24      grand daughter favorit book read love rhythm c...
# 25      copi smaller expect most didnt pay attent list...
# 26      rememb see show air televis year ago child sis...
# 27      favorit book mine littl girl would read time m...
# 28      book favorit mine sinc abl read one first intr...
# 29      wonder littl book love year ago twin love enjo...
# ...                                                   ...
# 364141  trader joe product good qualiti buy straight t...
# 364142  gave bulb receptionist local elder home volunt...
# 364143  tri read ingredi includ sweet agav extract por...
# 364144  wateri tasteless pinot noir planet cali tool m...
# 364145  usual drink green machin realli want tri blue ...
# 364146  purchas sever amarylli seller none compar than...
# 364147  neighborhood recent decid creat neighborhood g...
# 364148  true love gave christma bloom amarylli collect...
# 364149  bit hesit buy tea due low price truth high qua...
# 364150  avid tea drinker enjoy tea warm cold depend mo...
# 364151  wife use unsweeten ice tea year great your wat...
# 364152  product person pantri delici love kid ask panc...
# 364153  use product bit six month absolut love use alm...
# 364154  fat skinni zero wonder sweeten use everyth bak...
# 364155  sweetner great littl bit goe long way use seve...
# 364156  zero sweetner best ever use one drop cup coffe...
# 364157  great product not expens easi use ship quick e...
# 364158  use product month never back sweeten tast amaz...
# 364159  use bake instead sugar use cake whip cream any...
# 364160  ive use fat skinni zero sinc first introduc fi...
# 364161  fts zero best sweeten ever tri aftertast stoma...
# 364162  love sweeten use replac sugar everyth funni af...
# 364163  love love sweeten use bake unsweeten flavor co...
# 364164  packet powder sweeten usual littl dextros aka ...
# 364165  wonder product perfect use bake anyth need add...
# 364166  use fat skinni zero sweeten almost year sweete...
# 364167  tri sauc believ start littl sweet honey tast b...
# 364168  bought hazelnut past nocciola spread local sho...
# 364169  purchas product local store kid love quick eas...
# 364170  purchas send son whos away colleg deliv right ...
#
# [364171 rows x 12 columns]
