# %% [markdown]
# ## importing required libraries

# %%
## Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import sqlite3    ## SQL Interface
import pickle     ## Used to save your data - Converts objects to byte stream and vice versa

from sklearn.feature_extraction.text import CountVectorizer  ## TFIDF Model

## Modules to perform Text Preprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from matplotlib.colors import ListedColormap
from sklearn.metrics import accuracy_score
# %matplotlib inline
from sklearn.metrics import confusion_matrix


from sklearn.naive_bayes import BernoulliNB 
from sklearn.naive_bayes import MultinomialNB 

import gensim    ## To build Word2Vec model

# %% [markdown]
# ## reading the final.sqlite file

# %%
con=sqlite3.connect("final.sqlite")
data=pd.read_sql_query("select * from Reviews",con)
con.close
# Out:
# <function Connection.close>

# %% [markdown]
# ## separting the positive and negative review and creating a dataframe with all negative reviews and 65000 positive reviews

# %%
negative=data[data["Score"]==0 ][["Score","Time","CleanedSummary","CleanedText"]]
positive=data[data["Score"]==1 ][["Score","Time","CleanedSummary","CleanedText"]]
data=pd.concat([negative,positive.iloc[:65000,:]],axis=0,ignore_index=True)
data.sort_values("Time",inplace=True)

# %%
data
# Out:
#         Score        Time                                     CleanedSummary  \
# 89279       1   944092800                                entertainingl funny
# 99092       1   944438400                              modern day fairy tale
# 21840       0   948240000                   clamshell edition edited version
# 114632      1   951523200                bettlejuice bettlejuice bettlejuice
# 113134      1   961718400                                      great product
# 64542       1   965779200                                               must
# 88945       1   966297600  fresh original film master storyteller tim burton
# 76537       1   975974400                                       needs wilton
# 50919       0   992217600                                       casper ghost
# 8665        0   997228800                           great movie terrible dvd
# 118940      1  1003795200                                 nice bright colors
# 68698       1  1013040000                    entertaining odd fantasy comedy
# 95571       1  1022112000                                           way guys
# 98126       1  1036022400                                       great comedy
# 88732       1  1037750400                    say say twice third times charm
# 68142       1  1037923200                              good tim burton flick
# 51290       0  1040947200                             great movie turned bad
# 109762      1  1041120000                                        cvb fan gem
# 70326       1  1041638400                       easier use standard vacu vin
# 83379       1  1046044800                     outstanding flavor great price
# 78090       1  1052179200                                           vacu vin
# 44700       0  1052265600                                            puerile
# 46291       0  1055376000                                almost expired sept
# 17617       0  1064361600                 not actually use espresso machines
# 57757       1  1067040000                     ive chewed gum many times used
# 46591       0  1067385600                             woodstream gopher trap
# 74689       1  1067644800                                       gave coffees
# 64108       1  1067990400                                       fruits labor
# 93501       1  1068336000                                         stock item
# 14119       0  1068508800                                           not pure
# ...       ...         ...                                                ...
# 33857       0  1351209600                                    dont like taste
# 100140      1  1351209600                            best cornbread mix ever
# 19879       0  1351209600                                          not tasty
# 112189      1  1351209600                                      great service
# 32139       0  1351209600                                   defective device
# 117114      1  1351209600                           wont believe youll catch
# 91306       1  1351209600  aint coconut water better sun tropics coconut ...
# 113168      1  1351209600                                    little powerful
# 2882        0  1351209600                         yuk goes amazon buy cereal
# 109670      1  1351209600
# 44419       0  1351209600                                         didnt like
# 44605       0  1351209600                                                bad
# 88410       1  1351209600       good standard english breakfast decent brand
# 45758       0  1351209600                                               make
# 34418       0  1351209600                                       buyer beware
# 24573       0  1351209600                                reeses hershey bars
# 36374       0  1351209600                           toxic ingredients return
# 77720       1  1351209600                                benecol smart chews
# 93106       1  1351209600                                      tullys coffee
# 64296       1  1351209600                         works great simple install
# 76184       1  1351209600                                          cats love
# 99283       1  1351209600                                   love maui coffee
# 82781       1  1351209600                              tobin james excellent
# 31599       0  1351209600                                        consistency
# 6022        0  1351209600                                   new recipe awful
# 51897       0  1351209600                               tasted smelled stale
# 68671       1  1351209600                      rodeo drive crazy good coffee
# 96178       1  1351209600                             great swedish pastries
# 104270      1  1351209600                                          good deal
# 31807       0  1351209600                                       disappointed
#
#                                               CleanedText
# 89279   beetlejuic well written movi everyth excel act...
# 99092   twist rumplestiskin captur film star michael k...
# 21840   alway enjoy movi funni entertain didnt hesit p...
# 114632  happen say name three time michael keaten star...
# 113134  realli good idea final product outstand use de...
# 64542   easi use not make mess offer vibrant color not...
# 88945   great film dont even know sum first complet or...
# 76537   sick scad nasti toothpick counter tint concept...
# 50919   michael keaton bring distinguish characterist ...
# 8665    continu amaz shoddi treatment movi get dvd rel...
# 118940  bought decor dia los muerto skull ice ateco fo...
# 68698   two coupl geena davi alec baldwin die car acci...
# 95571   never dissapoint great gadget compani come bro...
# 98126   beetlejuic stori ghost alec baldwin geena davi...
# 88732   movi first came fifteen year ago father own vi...
# 68142   like tim burton movi general good one your mov...
# 51290   let know movi one person favorit ghost movi sa...
# 109762  notori earli album camper van beethoven get pr...
# 70326   use product standard cheaper pay premium buy p...
# 83379   year use starbuck decaf regular singl serv esp...
# 78090   although gift use keep wine also found invalu ...
# 44700   embarrass comedi come like child attent defici...
# 46291   return due short brief expir date sept would l...
# 17617   thing like point not roast drink northern ital...
# 57757   noth against product bother link top page buy ...
# 46591   poor excus gopher trap lot gopher use trap rec...
# 74689   groceri store kind coffe laid one tri tast lik...
# 64108   chatchi favorit afternoon treat becam mysteri ...
# 93501   usual purchas item smaller link pound stash fr...
# 14119   bake organ vanilla past realiz not vanilla ext...
# ...                                                   ...
# 33857   not like sour tast sour kind tast dont like sm...
# 100140  great corn bread mix perfect thanksgiv season ...
# 19879   love arnold plamer starbuck best black tea lem...
# 112189  not popcorn terrif advertis hull less order ar...
# 32139   instruct provid trap would not open tri set tr...
# 117114  use product mani year great method control ins...
# 91306   like young coconut tast like young coconut fre...
# 113168  mayb vegetarian eat realli healthi not junk fo...
# 2882    stuff tast like insert favorit negat adject am...
# 109670  made xylitol kill bacteria mouth day night tak...
# 44419   quit person didnt like flavour tast better ad ...
# 44605   wateri unpleas like yoohoo mix dirti dish wate...
# 88410   english breakfast tea higgin burk basic good t...
# 45758   seen lot review bitter tast coffe may listen n...
# 34418   nespresso make great coffe great machin nespre...
# 24573   way much compani laugh way bank wait til chris...
# 36374   review review amazon check label contain sure ...
# 77720   cholesterol read improv help chew believ howev...
# 93106   tulli coffe smoothest coffe market kona blend ...
# 64296   bought two easi instal work great problem wife...
# 76184   like brand flavor treat wont soft version one ...
# 99283   first experi maui coffe bring back maui souven...
# 82781   tobin jame excel wine one especi husband enjoy...
# 31599   purchas varieti pack martinson brown gold vend...
# 6022    use favorit anim cracker austin recent chang r...
# 51897   got back week rhine river cruis candi avail ti...
# 68671   rodeo drive absolut favorit readi order that f...
# 96178   svenhard variti pack pastri great individu wra...
# 104270  okay would prefer larger nugget type product e...
# 31807   daughter buy brand local differ expens box ass...
#
# [122110 rows x 4 columns]

# %%
data.head()
# Out:
#         Score       Time                       CleanedSummary  \
# 89279       1  944092800                  entertainingl funny
# 99092       1  944438400                modern day fairy tale
# 21840       0  948240000     clamshell edition edited version
# 114632      1  951523200  bettlejuice bettlejuice bettlejuice
# 113134      1  961718400                        great product
#
#                                               CleanedText
# 89279   beetlejuic well written movi everyth excel act...
# 99092   twist rumplestiskin captur film star michael k...
# 21840   alway enjoy movi funni entertain didnt hesit p...
# 114632  happen say name three time michael keaten star...
# 113134  realli good idea final product outstand use de...

# %% [markdown]
# ## performing binary BOW on cleaned Text  column

# %%
bow_vect=CountVectorizer(binary=True)
bow=bow_vect.fit_transform(data["CleanedText"])

# %%
X=bow

# %%
X
# Out:
# <122110x42264 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3974448 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## separating the class values

# %%
y=data["Score"].values

# %% [markdown]
# ## splitting the data for testing and training

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4337d96ffa73> in <module>()
# ----> 1 X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,shuffle=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2029         test_size = 0.25
#    2030
# -> 2031     arrays = indexable(*arrays)
#    2032
#    2033     if shuffle is False:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [2, 122110]

# %% [markdown]
# ## performing cross validation to find optimum value of alpha

# %%
alpha=np.linspace(0.1,1,10)
cv_scores=[]
for a in alpha:
    clf=BernoulliNB(alpha=a)
    scores=cross_val_score(clf,X_train,Y_train,cv=10,scoring="accuracy")
    cv_scores.append(scores.mean())
MSE=[1-x for x in cv_scores]
optimal_alpha=alpha[MSE.index(min(MSE))]

# %%
optimal_alpha
# Out:
# 0.4

# %%
plt.plot(alpha,MSE)

# %% [markdown]
# ### training the BernoulliNB model with the found optimum alpha value and testing the model to find accuracy and confusion matrix

# %%
clf=BernoulliNB(alpha=optimal_alpha)
clf.fit(X_train,Y_train)
y_pred=clf.predict(X_test)
acc=accuracy_score(Y_test,y_pred,normalize=True)*float(100)
print(acc)
confusion_matrix(Y_test,y_pred).T
# Out:
# 83.67046105970027
# array([[14623,  2343],
#        [ 3639, 16028]], dtype=int64)

# %% [markdown]
# ## feature extraction on both classes

# %%
idx=(-clf.feature_log_prob_).argsort()[:2,:50]
print("Top 50 words in negative reviews")
for i in idx[0]:
    print(bow_vect.get_feature_names()[i])
print("***************************************")
print("50 positive word ")
for i in idx[1]:
    print(bow_vect.get_feature_names()[i])
# Out:
# Top 50 words in negative reviews
# not
# tast
# like
# product
# one
# would
# tri
# flavor
# good
# buy
# get
# use
# dont
# even
# order
# much
# make
# realli
# time
# amazon
# love
# look
# eat
# box
# disappoint
# bought
# food
# purchas
# review
# first
# better
# packag
# want
# bad
# think
# coffe
# also
# bag
# could
# know
# say
# well
# great
# didnt
# thought
# price
# give
# made
# way
# got
# ***************************************
# 50 positive word
# not
# like
# tast
# love
# good
# great
# flavor
# one
# use
# tri
# product
# make
# get
# time
# buy
# would
# realli
# amazon
# find
# best
# also
# much
# price
# eat
# littl
# dont
# store
# well
# order
# food
# even
# coffe
# ive
# better
# recommend
# year
# tea
# day
# found
# high
# drink
# sweet
# mix
# bag
# give
# delici
# first
# enjoy
# want
# favorit

# %%
idx
# Out:
# array([[25156, 36643, 21055, 29069, 25865, 41508, 38155, 13588, 15506,
#          5122, 14997, 39590, 10791, 12414, 26069, 24040, 21961, 30143,
#         37531,  1168, 21541, 21425, 11376,  4380, 10322,  4331, 13854,
#         29485, 31061, 13445,  3469, 26599, 40473,  2632, 37262,  7416,
#          1058,  2652,  8348, 20140, 32174, 40761, 15823, 10088, 37340,
#         28915, 15183, 21847, 40616, 15596],
#        [25156, 21055, 36643, 21541, 15506, 15823, 13588, 25865, 39590,
#         38155, 29069, 21961, 14997, 37531,  5122, 41508, 30143,  1168,
#         13372,  3436,  1058, 24040, 28915, 11376, 21250, 10791, 35356,
#         40761, 26069, 13854, 12414,  7416, 19092,  3469, 30331, 41771,
#         36740,  9277, 14048, 17105, 11032, 36211, 23496,  2652, 15183,
#          9614, 13445, 11973, 40473, 13077]], dtype=int64)
